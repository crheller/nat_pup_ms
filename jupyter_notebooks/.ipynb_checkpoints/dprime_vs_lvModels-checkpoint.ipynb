# %% [markdown]
# ## Plot dprime after regressing out LV
# * Evaluate results for various xforms models

# %%
import sys
sys.path.append('/auto/users/hellerc/code/projects/nat_pupil_ms/')

from dprime2.load_dprime import load_dprime, filter_df, get_quad_mask

import matplotlib.pyplot as plt

# %%
# set regression method
cm = 'rm1'

# %%
# define lv modelstrings
xlv1a0 = 'ns.fs4.pup-ld.pop-st.pup-hrc-apm-psthfr-addmeta-' \
            'aev_stategain.SxR-lv.1xR.f.pred-stategain.2xR.lv_init.i0.xx1.t7-init.f0.t7.pLV0'
xlv1a01 = 'ns.fs4.pup-ld.pop-st.pup-hrc-apm-psthfr-addmeta-' \
            'aev_stategain.SxR-lv.1xR.f.pred-stategain.2xR.lv_init.i0.xx1.t7-init.f0.t7.pLV0,1'
xlv1a02 = 'ns.fs4.pup-ld.pop-st.pup-hrc-apm-psthfr-addmeta-' \
            'aev_stategain.SxR-lv.1xR.f.pred-stategain.2xR.lv_init.i0.xx1.t7-init.f0.t7.pLV0,2'
xlv1a03 = 'ns.fs4.pup-ld.pop-st.pup-hrc-apm-psthfr-addmeta-' \
            'aev_stategain.SxR-lv.1xR.f.pred-stategain.2xR.lv_init.i0.xx1.t7-init.f0.t7.pLV0,3'
    
xlv2a0 = 'ns.fs4.pup-ld.pop-st.pup-hrc-apm-psthfr-addmeta-' \
            'aev_stategain.SxR-lv.2xR.f2.pred-stategain.3xR.lv_init.i0.xx1.t7-init.f0.t7.pLV0'
xlv2a01 = 'ns.fs4.pup-ld.pop-st.pup-hrc-apm-psthfr-addmeta-' \
            'aev_stategain.SxR-lv.2xR.f2.pred-stategain.3xR.lv_init.i0.xx1.t7-init.f0.t7.pLV0,1'
xlv2a02 = 'ns.fs4.pup-ld.pop-st.pup-hrc-apm-psthfr-addmeta-' \
            'aev_stategain.SxR-lv.2xR.f2.pred-stategain.3xR.lv_init.i0.xx1.t7-init.f0.t7.pLV0,2'
xlv2a03 = 'ns.fs4.pup-ld.pop-st.pup-hrc-apm-psthfr-addmeta-' \
            'aev_stategain.SxR-lv.2xR.f2.pred-stategain.3xR.lv_init.i0.xx1.t7-init.f0.t7.pLV0,3'
    
xlv3a0 = 'ns.fs4.pup-ld.pop-st.pup-hrc-apm-psthfr-addmeta-' \
            'aev_stategain.SxR-lv.3xR.f3.pred-stategain.4xR.lv_init.i0.xx1.t7-init.f0.t7.pLV0'
xlv3a01 = 'ns.fs4.pup-ld.pop-st.pup-hrc-apm-psthfr-addmeta-' \
            'aev_stategain.SxR-lv.3xR.f3.pred-stategain.4xR.lv_init.i0.xx1.t7-init.f0.t7.pLV0,1'
xlv3a02 = 'ns.fs4.pup-ld.pop-st.pup-hrc-apm-psthfr-addmeta-' \
            'aev_stategain.SxR-lv.3xR.f3.pred-stategain.4xR.lv_init.i0.xx1.t7-init.f0.t7.pLV0,2'
xlv3a03 = 'ns.fs4.pup-ld.pop-st.pup-hrc-apm-psthfr-addmeta-' \
            'aev_stategain.SxR-lv.3xR.f3.pred-stategain.4xR.lv_init.i0.xx1.t7-init.f0.t7.pLV0,3'

# %% [markdown]
# ## RAW DATA

# %%
# for df / qudrant filtering purposes
dp_sp = load_dprime('dprime_sp_sia')
dp_all = load_dprime('dprime_all')

# raw / pr results
raw_bp = load_dprime('dprime_bp_sia')
raw_sp = load_dprime('dprime_sp_sia')
bp_pr = load_dprime('dprime_bp_pr_sia_{}'.format(cm))
sp_pr = load_dprime('dprime_sp_pr_sia_{}'.format(cm))

# load all dprime for various xforms models (lv regression - differen n LVs / hyperparameter constraints
bp_lv1_a0 = load_dprime('dprime_bp_pr_lvr_sia_{}'.format(cm), xforms_model=xlv1a0)
bp_lv1_a01 = load_dprime('dprime_bp_pr_lvr_sia_{}'.format(cm), xforms_model=xlv1a01)
bp_lv1_a02 = load_dprime('dprime_bp_pr_lvr_sia_{}'.format(cm), xforms_model=xlv1a02)
bp_lv1_a03 = load_dprime('dprime_bp_pr_lvr_sia_{}'.format(cm), xforms_model=xlv1a03)
bp_lv2_a0 = load_dprime('dprime_bp_pr_lvr_sia_{}'.format(cm), xforms_model=xlv2a0)
bp_lv2_a01 = load_dprime('dprime_bp_pr_lvr_sia_{}'.format(cm), xforms_model=xlv2a01)
bp_lv2_a02 = load_dprime('dprime_bp_pr_lvr_sia_{}'.format(cm), xforms_model=xlv2a02)
bp_lv2_a03 = load_dprime('dprime_bp_pr_lvr_sia_{}'.format(cm), xforms_model=xlv2a03)
bp_lv3_a0 = load_dprime('dprime_bp_pr_lvr_sia_{}'.format(cm), xforms_model=xlv3a0)
bp_lv3_a01 = load_dprime('dprime_bp_pr_lvr_sia_{}'.format(cm), xforms_model=xlv3a01)
bp_lv3_a02 = load_dprime('dprime_bp_pr_lvr_sia_{}'.format(cm), xforms_model=xlv3a02)
bp_lv3_a03 = load_dprime('dprime_bp_pr_lvr_sia_{}'.format(cm), xforms_model=xlv3a03)

sp_lv1_a0 = load_dprime('dprime_sp_pr_lvr_sia_{}'.format(cm), xforms_model=xlv1a0)
sp_lv1_a01 = load_dprime('dprime_sp_pr_lvr_sia_{}'.format(cm), xforms_model=xlv1a01)
sp_lv1_a02 = load_dprime('dprime_sp_pr_lvr_sia_{}'.format(cm), xforms_model=xlv1a02)
sp_lv1_a03 = load_dprime('dprime_sp_pr_lvr_sia_{}'.format(cm), xforms_model=xlv1a03)
sp_lv2_a0 = load_dprime('dprime_sp_pr_lvr_sia_{}'.format(cm), xforms_model=xlv2a0)
sp_lv2_a01 = load_dprime('dprime_sp_pr_lvr_sia_{}'.format(cm), xforms_model=xlv2a01)
sp_lv2_a02 = load_dprime('dprime_sp_pr_lvr_sia_{}'.format(cm), xforms_model=xlv2a02)
sp_lv2_a03 = load_dprime('dprime_sp_pr_lvr_sia_{}'.format(cm), xforms_model=xlv2a03)
sp_lv3_a0 = load_dprime('dprime_sp_pr_lvr_sia_{}'.format(cm), xforms_model=xlv3a0)
sp_lv3_a01 = load_dprime('dprime_sp_pr_lvr_sia_{}'.format(cm), xforms_model=xlv3a01)
sp_lv3_a02 = load_dprime('dprime_sp_pr_lvr_sia_{}'.format(cm), xforms_model=xlv3a02)
sp_lv3_a03 = load_dprime('dprime_sp_pr_lvr_sia_{}'.format(cm), xforms_model=xlv3a03)

df_list = [bp_lv1_a0, bp_lv1_a01, bp_lv1_a02, bp_lv1_a03,
          bp_lv2_a0, bp_lv2_a01, bp_lv2_a02, bp_lv2_a03,
          bp_lv3_a0, bp_lv3_a01, bp_lv3_a02, bp_lv3_a03,
          sp_lv1_a0, sp_lv1_a01, sp_lv1_a02, sp_lv1_a03,
          sp_lv2_a0, sp_lv2_a01, sp_lv2_a02, sp_lv2_a03,
          sp_lv3_a0, sp_lv3_a01, sp_lv3_a02, sp_lv3_a03, 
          raw_bp, raw_sp, bp_pr, sp_pr, dp_all, dp_sp]
[bp_lv1_a0, bp_lv1_a01, bp_lv1_a02, bp_lv1_a03,
          bp_lv2_a0, bp_lv2_a01, bp_lv2_a02, bp_lv2_a03,
          bp_lv3_a0, bp_lv3_a01, bp_lv3_a02, bp_lv3_a03,
          sp_lv1_a0, sp_lv1_a01, sp_lv1_a02, sp_lv1_a03,
          sp_lv2_a0, sp_lv2_a01, sp_lv2_a02, sp_lv2_a03,
          sp_lv3_a0, sp_lv3_a01, sp_lv3_a02, sp_lv3_a03, 
          raw_bp, raw_sp, bp_pr, sp_pr, dp_all, dp_sp] = filter_df(df_list, dp_all, dp_sp)

# %%
# just for top two quadrants
q1_mask = get_quad_mask(dp_all, dp_sp, 1)
q2_mask = get_quad_mask(dp_all, dp_sp, 2)
q_mask = q1_mask | q2_mask

raw_diff = (raw_bp[q_mask]['dprime'] - raw_sp[q_mask]['dprime']).mean()
raw_sem = (raw_bp[q_mask]['dprime'] - raw_sp[q_mask]['dprime']).sem()
pr_diff = (bp_pr[q_mask]['dprime'] - sp_pr[q_mask]['dprime']).mean()
pr_sem = (bp_pr[q_mask]['dprime'] - sp_pr[q_mask]['dprime']).sem()

f, ax = plt.subplots(1, 1, figsize=(10, 8))

ax.errorbar(-1, raw_diff, yerr=raw_sem,
                marker='.', markersize=10, color='k', label='raw', lw=2)
ax.errorbar(-1, pr_diff, yerr=pr_sem,
                marker='.', markersize=10, color='grey', label='pupil-corrected', lw=2)

ax.errorbar([0, 1, 2, 3], [(bp_lv1_a0[q_mask]['dprime'] - sp_lv1_a0[q_mask]['dprime']).mean(),
                          (bp_lv1_a01[q_mask]['dprime'] - sp_lv1_a01[q_mask]['dprime']).mean(),
                          (bp_lv1_a02[q_mask]['dprime'] - sp_lv1_a02[q_mask]['dprime']).mean(),
                          (bp_lv1_a03[q_mask]['dprime'] - sp_lv1_a03[q_mask]['dprime']).mean()], 
                          yerr=[(bp_lv1_a0[q_mask]['dprime'] - sp_lv1_a0[q_mask]['dprime']).sem(),
                          (bp_lv1_a01[q_mask]['dprime'] - sp_lv1_a01[q_mask]['dprime']).sem(),
                          (bp_lv1_a02[q_mask]['dprime'] - sp_lv1_a02[q_mask]['dprime']).sem(),
                          (bp_lv1_a03[q_mask]['dprime'] - sp_lv1_a03[q_mask]['dprime']).sem()], 
                          label='1-D LV', marker='.', markersize=10, lw=2)
ax.errorbar([0, 1, 2, 3], [(bp_lv2_a0[q_mask]['dprime'] - sp_lv2_a0[q_mask]['dprime']).mean(),
                          (bp_lv2_a01[q_mask]['dprime'] - sp_lv2_a01[q_mask]['dprime']).mean(),
                          (bp_lv2_a02[q_mask]['dprime'] - sp_lv2_a02[q_mask]['dprime']).mean(),
                          (bp_lv2_a03[q_mask]['dprime'] - sp_lv2_a03[q_mask]['dprime']).mean()], 
                          yerr=[(bp_lv2_a0[q_mask]['dprime'] - sp_lv2_a0[q_mask]['dprime']).sem(),
                          (bp_lv2_a01[q_mask]['dprime'] - sp_lv2_a01[q_mask]['dprime']).sem(),
                          (bp_lv2_a02[q_mask]['dprime'] - sp_lv2_a02[q_mask]['dprime']).sem(),
                          (bp_lv2_a03[q_mask]['dprime'] - sp_lv2_a03[q_mask]['dprime']).sem()], 
                          label='2-D LV', marker='.', markersize=10, lw=2)
ax.errorbar([0, 1, 2, 3], [(bp_lv3_a0[q_mask]['dprime'] - sp_lv3_a0[q_mask]['dprime']).mean(),
                          (bp_lv3_a01[q_mask]['dprime'] - sp_lv3_a01[q_mask]['dprime']).mean(),
                          (bp_lv3_a02[q_mask]['dprime'] - sp_lv3_a02[q_mask]['dprime']).mean(),
                          (bp_lv3_a03[q_mask]['dprime'] - sp_lv3_a03[q_mask]['dprime']).mean()], 
                          yerr=[(bp_lv3_a0[q_mask]['dprime'] - sp_lv3_a0[q_mask]['dprime']).sem(),
                          (bp_lv3_a01[q_mask]['dprime'] - sp_lv3_a01[q_mask]['dprime']).sem(),
                          (bp_lv3_a02[q_mask]['dprime'] - sp_lv3_a02[q_mask]['dprime']).sem(),
                          (bp_lv3_a03[q_mask]['dprime'] - sp_lv3_a03[q_mask]['dprime']).sem()], 
                          label='3-D LV', marker='.', markersize=10, lw=2)

ax.axhline(0, linestyle='--', color='k')
ax.legend()

ax.set_ylabel('big minus small')
ax.set_xlabel('Hyerparameter constraint')
ax.set_xticks([-1, 0, 1, 2, 3])
ax.set_xticklabels(['NA', 0.0, 0.1, 0.2, 0.3])

ax.set_title('Delta dprime, real data')

plt.show()

# %% [markdown]
# ## FIRST-ORDER SIMULATION

# %%
# for df / qudrant filtering purposes
dp_sp = load_dprime('dprime_sp_sia')
dp_all = load_dprime('dprime_all')

# raw / pr results
sim1_bp = load_dprime('dprime_bp_sim1_sia_uMatch')
sim1_sp = load_dprime('dprime_sp_sim1_sia_uMatch')
sim1_bp_pr = load_dprime('dprime_bp_pr_sim1_sia_{}_uMatch'.format(cm))
sim1_sp_pr = load_dprime('dprime_sp_pr_sim1_sia_{}_uMatch'.format(cm))

# load all dprime for various xforms models (lv regression - differen n LVs / hyperparameter constraints
bp_lv1_a0 = load_dprime('dprime_bp_pr_lvr_sim1_sia_{}_uMatch'.format(cm), xforms_model=xlv1a0)
bp_lv1_a01 = load_dprime('dprime_bp_pr_lvr_sim1_sia_{}_uMatch'.format(cm), xforms_model=xlv1a01)
bp_lv1_a02 = load_dprime('dprime_bp_pr_lvr_sim1_sia_{}_uMatch'.format(cm), xforms_model=xlv1a02)
bp_lv1_a03 = load_dprime('dprime_bp_pr_lvr_sim1_sia_{}_uMatch'.format(cm), xforms_model=xlv1a03)
bp_lv2_a0 = load_dprime('dprime_bp_pr_lvr_sim1_sia_{}_uMatch'.format(cm), xforms_model=xlv2a0)
bp_lv2_a01 = load_dprime('dprime_bp_pr_lvr_sim1_sia_{}_uMatch'.format(cm), xforms_model=xlv2a01)
bp_lv2_a02 = load_dprime('dprime_bp_pr_lvr_sim1_sia_{}_uMatch'.format(cm), xforms_model=xlv2a02)
bp_lv2_a03 = load_dprime('dprime_bp_pr_lvr_sim1_sia_{}_uMatch'.format(cm), xforms_model=xlv2a03)
bp_lv3_a0 = load_dprime('dprime_bp_pr_lvr_sim1_sia_{}_uMatch'.format(cm), xforms_model=xlv3a0)
bp_lv3_a01 = load_dprime('dprime_bp_pr_lvr_sim1_sia_{}_uMatch'.format(cm), xforms_model=xlv3a01)
bp_lv3_a02 = load_dprime('dprime_bp_pr_lvr_sim1_sia_{}_uMatch'.format(cm), xforms_model=xlv3a02)
bp_lv3_a03 = load_dprime('dprime_bp_pr_lvr_sim1_sia_{}_uMatch'.format(cm), xforms_model=xlv3a03)

sp_lv1_a0 = load_dprime('dprime_sp_pr_lvr_sim1_sia_{}_uMatch'.format(cm), xforms_model=xlv1a0)
sp_lv1_a01 = load_dprime('dprime_sp_pr_lvr_sim1_sia_{}_uMatch'.format(cm), xforms_model=xlv1a01)
sp_lv1_a02 = load_dprime('dprime_sp_pr_lvr_sim1_sia_{}_uMatch'.format(cm), xforms_model=xlv1a02)
sp_lv1_a03 = load_dprime('dprime_sp_pr_lvr_sim1_sia_{}_uMatch'.format(cm), xforms_model=xlv1a03)
sp_lv2_a0 = load_dprime('dprime_sp_pr_lvr_sim1_sia_{}_uMatch'.format(cm), xforms_model=xlv2a0)
sp_lv2_a01 = load_dprime('dprime_sp_pr_lvr_sim1_sia_{}_uMatch'.format(cm), xforms_model=xlv2a01)
sp_lv2_a02 = load_dprime('dprime_sp_pr_lvr_sim1_sia_{}_uMatch'.format(cm), xforms_model=xlv2a02)
sp_lv2_a03 = load_dprime('dprime_sp_pr_lvr_sim1_sia_{}_uMatch'.format(cm), xforms_model=xlv2a03)
sp_lv3_a0 = load_dprime('dprime_sp_pr_lvr_sim1_sia_{}_uMatch'.format(cm), xforms_model=xlv3a0)
sp_lv3_a01 = load_dprime('dprime_sp_pr_lvr_sim1_sia_{}_uMatch'.format(cm), xforms_model=xlv3a01)
sp_lv3_a02 = load_dprime('dprime_sp_pr_lvr_sim1_sia_{}_uMatch'.format(cm), xforms_model=xlv3a02)
sp_lv3_a03 = load_dprime('dprime_sp_pr_lvr_sim1_sia_{}_uMatch'.format(cm), xforms_model=xlv3a03)

df_list = [bp_lv1_a0, bp_lv1_a01, bp_lv1_a02, bp_lv1_a03,
          bp_lv2_a0, bp_lv2_a01, bp_lv2_a02, bp_lv2_a03,
          bp_lv3_a0, bp_lv3_a01, bp_lv3_a02, bp_lv3_a03,
          sp_lv1_a0, sp_lv1_a01, sp_lv1_a02, sp_lv1_a03,
          sp_lv2_a0, sp_lv2_a01, sp_lv2_a02, sp_lv2_a03,
          sp_lv3_a0, sp_lv3_a01, sp_lv3_a02, sp_lv3_a03, 
          sim1_bp, sim1_sp, sim1_bp_pr, sim1_sp_pr, dp_all, dp_sp]
[bp_lv1_a0, bp_lv1_a01, bp_lv1_a02, bp_lv1_a03,
          bp_lv2_a0, bp_lv2_a01, bp_lv2_a02, bp_lv2_a03,
          bp_lv3_a0, bp_lv3_a01, bp_lv3_a02, bp_lv3_a03,
          sp_lv1_a0, sp_lv1_a01, sp_lv1_a02, sp_lv1_a03,
          sp_lv2_a0, sp_lv2_a01, sp_lv2_a02, sp_lv2_a03,
          sp_lv3_a0, sp_lv3_a01, sp_lv3_a02, sp_lv3_a03, 
          sim1_bp, sim1_sp, sim1_bp_pr, sim1_sp_pr, dp_all, dp_sp] = filter_df(df_list, dp_all, dp_sp)

# %%
# just for top two quadrants
q1_mask = get_quad_mask(dp_all, raw_sp, 1)
q2_mask = get_quad_mask(dp_all, raw_sp, 2)
q_mask = q1_mask | q2_mask

raw_diff = (sim1_bp[q_mask]['dprime'] - sim1_sp[q_mask]['dprime']).mean()
raw_sem = (sim1_bp[q_mask]['dprime'] - sim1_sp[q_mask]['dprime']).sem()
pr_diff = (sim1_bp_pr[q_mask]['dprime'] - sim1_sp_pr[q_mask]['dprime']).mean()
pr_sem = (sim1_bp_pr[q_mask]['dprime'] - sim1_sp_pr[q_mask]['dprime']).sem()

f, ax = plt.subplots(1, 1, figsize=(10, 8))

ax.errorbar(-1, raw_diff, yerr=raw_sem,
                marker='.', markersize=10, color='k', label='raw', lw=2)
ax.errorbar(-1, pr_diff, yerr=pr_sem,
                marker='.', markersize=10, color='grey', label='pupil-corrected', lw=2)

ax.errorbar([0, 1, 2, 3], [(bp_lv1_a0[q_mask]['dprime'] - sp_lv1_a0[q_mask]['dprime']).mean(),
                          (bp_lv1_a01[q_mask]['dprime'] - sp_lv1_a01[q_mask]['dprime']).mean(),
                          (bp_lv1_a02[q_mask]['dprime'] - sp_lv1_a02[q_mask]['dprime']).mean(),
                          (bp_lv1_a03[q_mask]['dprime'] - sp_lv1_a03[q_mask]['dprime']).mean()], 
                          yerr=[(bp_lv1_a0[q_mask]['dprime'] - sp_lv1_a0[q_mask]['dprime']).sem(),
                          (bp_lv1_a01[q_mask]['dprime'] - sp_lv1_a01[q_mask]['dprime']).sem(),
                          (bp_lv1_a02[q_mask]['dprime'] - sp_lv1_a02[q_mask]['dprime']).sem(),
                          (bp_lv1_a03[q_mask]['dprime'] - sp_lv1_a03[q_mask]['dprime']).sem()], 
                          label='1-D LV', marker='.', markersize=10, lw=2)
ax.errorbar([0, 1, 2, 3], [(bp_lv2_a0[q_mask]['dprime'] - sp_lv2_a0[q_mask]['dprime']).mean(),
                          (bp_lv2_a01[q_mask]['dprime'] - sp_lv2_a01[q_mask]['dprime']).mean(),
                          (bp_lv2_a02[q_mask]['dprime'] - sp_lv2_a02[q_mask]['dprime']).mean(),
                          (bp_lv2_a03[q_mask]['dprime'] - sp_lv2_a03[q_mask]['dprime']).mean()], 
                          yerr=[(bp_lv2_a0[q_mask]['dprime'] - sp_lv2_a0[q_mask]['dprime']).sem(),
                          (bp_lv2_a01[q_mask]['dprime'] - sp_lv2_a01[q_mask]['dprime']).sem(),
                          (bp_lv2_a02[q_mask]['dprime'] - sp_lv2_a02[q_mask]['dprime']).sem(),
                          (bp_lv2_a03[q_mask]['dprime'] - sp_lv2_a03[q_mask]['dprime']).sem()], 
                          label='2-D LV', marker='.', markersize=10, lw=2)
ax.errorbar([0, 1, 2, 3], [(bp_lv3_a0[q_mask]['dprime'] - sp_lv3_a0[q_mask]['dprime']).mean(),
                          (bp_lv3_a01[q_mask]['dprime'] - sp_lv3_a01[q_mask]['dprime']).mean(),
                          (bp_lv3_a02[q_mask]['dprime'] - sp_lv3_a02[q_mask]['dprime']).mean(),
                          (bp_lv3_a03[q_mask]['dprime'] - sp_lv3_a03[q_mask]['dprime']).mean()], 
                          yerr=[(bp_lv3_a0[q_mask]['dprime'] - sp_lv3_a0[q_mask]['dprime']).sem(),
                          (bp_lv3_a01[q_mask]['dprime'] - sp_lv3_a01[q_mask]['dprime']).sem(),
                          (bp_lv3_a02[q_mask]['dprime'] - sp_lv3_a02[q_mask]['dprime']).sem(),
                          (bp_lv3_a03[q_mask]['dprime'] - sp_lv3_a03[q_mask]['dprime']).sem()], 
                          label='3-D LV', marker='.', markersize=10, lw=2)

ax.axhline(0, linestyle='--', color='k')
ax.legend()

ax.set_ylabel('big minus small')
ax.set_xlabel('Hyerparameter constraint')
ax.set_xticks([-1, 0, 1, 2, 3])
ax.set_xticklabels(['NA', 0.0, 0.1, 0.2, 0.3])

ax.set_title('Delta dprime, 1st order simulation data')

plt.show()

# %% [markdown]
# ## SECOND ORDER SIMULATION

# %%
# for df / qudrant filtering purposes
dp_sp = load_dprime('dprime_sp_sia')
dp_all = load_dprime('dprime_all')

# raw / pr results
sim2_bp = load_dprime('dprime_bp_sim2_sia_uMatch')
sim2_sp = load_dprime('dprime_sp_sim2_sia_uMatch')
sim2_bp_pr = load_dprime('dprime_bp_pr_sim2_sia_{}_uMatch'.format(cm))
sim2_sp_pr = load_dprime('dprime_sp_pr_sim2_sia_{}_uMatch'.format(cm))

# load all dprime for various xforms models (lv regression - differen n LVs / hyperparameter constraints
bp_lv1_a0 = load_dprime('dprime_bp_pr_lvr_sim2_sia_{}_uMatch'.format(cm), xforms_model=xlv1a0)
bp_lv1_a01 = load_dprime('dprime_bp_pr_lvr_sim2_sia_{}_uMatch'.format(cm), xforms_model=xlv1a01)
bp_lv1_a02 = load_dprime('dprime_bp_pr_lvr_sim2_sia_{}_uMatch'.format(cm), xforms_model=xlv1a02)
bp_lv1_a03 = load_dprime('dprime_bp_pr_lvr_sim2_sia_{}_uMatch'.format(cm), xforms_model=xlv1a03)
bp_lv2_a0 = load_dprime('dprime_bp_pr_lvr_sim2_sia_{}_uMatch'.format(cm), xforms_model=xlv2a0)
bp_lv2_a01 = load_dprime('dprime_bp_pr_lvr_sim2_sia_{}_uMatch'.format(cm), xforms_model=xlv2a01)
bp_lv2_a02 = load_dprime('dprime_bp_pr_lvr_sim2_sia_{}_uMatch'.format(cm), xforms_model=xlv2a02)
bp_lv2_a03 = load_dprime('dprime_bp_pr_lvr_sim2_sia_{}_uMatch'.format(cm), xforms_model=xlv2a03)
bp_lv3_a0 = load_dprime('dprime_bp_pr_lvr_sim2_sia_{}_uMatch'.format(cm), xforms_model=xlv3a0)
bp_lv3_a01 = load_dprime('dprime_bp_pr_lvr_sim2_sia_{}_uMatch'.format(cm), xforms_model=xlv3a01)
bp_lv3_a02 = load_dprime('dprime_bp_pr_lvr_sim2_sia_{}_uMatch'.format(cm), xforms_model=xlv3a02)
bp_lv3_a03 = load_dprime('dprime_bp_pr_lvr_sim2_sia_{}_uMatch'.format(cm), xforms_model=xlv3a03)

sp_lv1_a0 = load_dprime('dprime_sp_pr_lvr_sim2_sia_{}_uMatch'.format(cm), xforms_model=xlv1a0)
sp_lv1_a01 = load_dprime('dprime_sp_pr_lvr_sim2_sia_{}_uMatch'.format(cm), xforms_model=xlv1a01)
sp_lv1_a02 = load_dprime('dprime_sp_pr_lvr_sim2_sia_{}_uMatch'.format(cm), xforms_model=xlv1a02)
sp_lv1_a03 = load_dprime('dprime_sp_pr_lvr_sim2_sia_{}_uMatch'.format(cm), xforms_model=xlv1a03)
sp_lv2_a0 = load_dprime('dprime_sp_pr_lvr_sim2_sia_{}_uMatch'.format(cm), xforms_model=xlv2a0)
sp_lv2_a01 = load_dprime('dprime_sp_pr_lvr_sim2_sia_{}_uMatch'.format(cm), xforms_model=xlv2a01)
sp_lv2_a02 = load_dprime('dprime_sp_pr_lvr_sim2_sia_{}_uMatch'.format(cm), xforms_model=xlv2a02)
sp_lv2_a03 = load_dprime('dprime_sp_pr_lvr_sim2_sia_{}_uMatch'.format(cm), xforms_model=xlv2a03)
sp_lv3_a0 = load_dprime('dprime_sp_pr_lvr_sim2_sia_{}_uMatch'.format(cm), xforms_model=xlv3a0)
sp_lv3_a01 = load_dprime('dprime_sp_pr_lvr_sim2_sia_{}_uMatch'.format(cm), xforms_model=xlv3a01)
sp_lv3_a02 = load_dprime('dprime_sp_pr_lvr_sim2_sia_{}_uMatch'.format(cm), xforms_model=xlv3a02)
sp_lv3_a03 = load_dprime('dprime_sp_pr_lvr_sim2_sia_{}_uMatch'.format(cm), xforms_model=xlv3a03)

df_list = [bp_lv1_a0, bp_lv1_a01, bp_lv1_a02, bp_lv1_a03,
          bp_lv2_a0, bp_lv2_a01, bp_lv2_a02, bp_lv2_a03,
          bp_lv3_a0, bp_lv3_a01, bp_lv3_a02, bp_lv3_a03,
          sp_lv1_a0, sp_lv1_a01, sp_lv1_a02, sp_lv1_a03,
          sp_lv2_a0, sp_lv2_a01, sp_lv2_a02, sp_lv2_a03,
          sp_lv3_a0, sp_lv3_a01, sp_lv3_a02, sp_lv3_a03, 
          sim2_bp, sim2_sp, sim2_bp_pr, sim2_sp_pr, dp_all, dp_sp]
[bp_lv1_a0, bp_lv1_a01, bp_lv1_a02, bp_lv1_a03,
          bp_lv2_a0, bp_lv2_a01, bp_lv2_a02, bp_lv2_a03,
          bp_lv3_a0, bp_lv3_a01, bp_lv3_a02, bp_lv3_a03,
          sp_lv1_a0, sp_lv1_a01, sp_lv1_a02, sp_lv1_a03,
          sp_lv2_a0, sp_lv2_a01, sp_lv2_a02, sp_lv2_a03,
          sp_lv3_a0, sp_lv3_a01, sp_lv3_a02, sp_lv3_a03, 
          sim2_bp, sim2_sp, sim2_bp_pr, sim2_sp_pr, dp_all, dp_sp] = filter_df(df_list, dp_all, dp_sp)

# %%
# just for top two quadrants
q1_mask = get_quad_mask(dp_all, raw_sp, 1)
q2_mask = get_quad_mask(dp_all, raw_sp, 2)
q_mask = q1_mask | q2_mask

raw_diff = (sim2_bp[q_mask]['dprime'] - sim2_sp[q_mask]['dprime']).mean()
raw_sem = (sim2_bp[q_mask]['dprime'] - sim2_sp[q_mask]['dprime']).sem()
pr_diff = (sim2_bp_pr[q_mask]['dprime'] - sim2_sp_pr[q_mask]['dprime']).mean()
pr_sem = (sim2_bp_pr[q_mask]['dprime'] - sim2_sp_pr[q_mask]['dprime']).sem()

f, ax = plt.subplots(1, 1, figsize=(10, 8))

ax.errorbar(-1, raw_diff, yerr=raw_sem,
                marker='.', markersize=10, color='k', label='raw', lw=2)
ax.errorbar(-1, pr_diff, yerr=pr_sem,
                marker='.', markersize=10, color='grey', label='pupil-corrected', lw=2)

ax.errorbar([0, 1, 2, 3], [(bp_lv1_a0[q_mask]['dprime'] - sp_lv1_a0[q_mask]['dprime']).mean(),
                          (bp_lv1_a01[q_mask]['dprime'] - sp_lv1_a01[q_mask]['dprime']).mean(),
                          (bp_lv1_a02[q_mask]['dprime'] - sp_lv1_a02[q_mask]['dprime']).mean(),
                          (bp_lv1_a03[q_mask]['dprime'] - sp_lv1_a03[q_mask]['dprime']).mean()], 
                          yerr=[(bp_lv1_a0[q_mask]['dprime'] - sp_lv1_a0[q_mask]['dprime']).sem(),
                          (bp_lv1_a01[q_mask]['dprime'] - sp_lv1_a01[q_mask]['dprime']).sem(),
                          (bp_lv1_a02[q_mask]['dprime'] - sp_lv1_a02[q_mask]['dprime']).sem(),
                          (bp_lv1_a03[q_mask]['dprime'] - sp_lv1_a03[q_mask]['dprime']).sem()], 
                          label='1-D LV', marker='.', markersize=10, lw=2)
ax.errorbar([0, 1, 2, 3], [(bp_lv2_a0[q_mask]['dprime'] - sp_lv2_a0[q_mask]['dprime']).mean(),
                          (bp_lv2_a01[q_mask]['dprime'] - sp_lv2_a01[q_mask]['dprime']).mean(),
                          (bp_lv2_a02[q_mask]['dprime'] - sp_lv2_a02[q_mask]['dprime']).mean(),
                          (bp_lv2_a03[q_mask]['dprime'] - sp_lv2_a03[q_mask]['dprime']).mean()], 
                          yerr=[(bp_lv2_a0[q_mask]['dprime'] - sp_lv2_a0[q_mask]['dprime']).sem(),
                          (bp_lv2_a01[q_mask]['dprime'] - sp_lv2_a01[q_mask]['dprime']).sem(),
                          (bp_lv2_a02[q_mask]['dprime'] - sp_lv2_a02[q_mask]['dprime']).sem(),
                          (bp_lv2_a03[q_mask]['dprime'] - sp_lv2_a03[q_mask]['dprime']).sem()], 
                          label='2-D LV', marker='.', markersize=10, lw=2)
ax.errorbar([0, 1, 2, 3], [(bp_lv3_a0[q_mask]['dprime'] - sp_lv3_a0[q_mask]['dprime']).mean(),
                          (bp_lv3_a01[q_mask]['dprime'] - sp_lv3_a01[q_mask]['dprime']).mean(),
                          (bp_lv3_a02[q_mask]['dprime'] - sp_lv3_a02[q_mask]['dprime']).mean(),
                          (bp_lv3_a03[q_mask]['dprime'] - sp_lv3_a03[q_mask]['dprime']).mean()], 
                          yerr=[(bp_lv3_a0[q_mask]['dprime'] - sp_lv3_a0[q_mask]['dprime']).sem(),
                          (bp_lv3_a01[q_mask]['dprime'] - sp_lv3_a01[q_mask]['dprime']).sem(),
                          (bp_lv3_a02[q_mask]['dprime'] - sp_lv3_a02[q_mask]['dprime']).sem(),
                          (bp_lv3_a03[q_mask]['dprime'] - sp_lv3_a03[q_mask]['dprime']).sem()], 
                          label='3-D LV', marker='.', markersize=10, lw=2)

ax.axhline(0, linestyle='--', color='k')
ax.legend()

ax.set_ylabel('big minus small')
ax.set_xlabel('Hyerparameter constraint')
ax.set_xticks([-1, 0, 1, 2, 3])
ax.set_xticklabels(['NA', 0.0, 0.1, 0.2, 0.3])

ax.set_title('Delta dprime, 2nd order simulation data')

plt.show()
